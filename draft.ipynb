# %%
from usernames import usernames
import pandas as pd

# %%
with open('./log/log_verification.txt') as f:
    file_str = f.read()
file_str.split('\n')
# Out:
# ['kvspek@gmail.com',
#  'spektork@post.bgu.ac.il',
#  'kev_backup@yahoo.com',
#  'cool_table@yahoo.com',
#  'cool_table2@yahoo.com',
#  'cool_table3@yahoo.com',
#  'cool_table4@yahoo.com',
#  'cool_table5@yahoo.com',
#  'cool_table6@yahoo.com',
#  'cool_table7@yahoo.com',
#  'cool_table8@yahoo.com',
#  'bot_alon1@yahoo.com',
#  'bot_alon2@yahoo.com',
#  'bot_alon3@yahoo.com',
#  'bot_alon4@yahoo.com',
#  'bot_alon5@yahoo.com',
#  'bot_alon6@yahoo.com',
#  'bot_alon7@yahoo.com',
#  'bot_alon8@yahoo.com',
#  'bot_alon9@yahoo.com',
#  'proton_velo1@protonmail.com',
#  'proton_velo2@protonmail.com',
#  'proton_velo3@protonmail.com',
#  'proton_velo4@protonmail.com',
#  'proton_velo5@protonmail.com',
#  'velo.yan1@yandex.com',
#  'velo.yan2@yandex.com',
#  'velo.yan3@yandex.com',
#  'velo.yan4@yandex.com',
#  'velo.yan5@yandex.com',
#  'velo.yan6@yandex.com',
#  'velo.yan7@yandex.com',
#  'velo.yan8@yandex.com',
#  'velo.yan12@yandex.com',
#  'velo.yan13@yandex.com',
# ...

# %%
for user in usernames:
    if user not in file_str:
        print(user)
# Out:
# velo.yan34@yandex.com
# velo.yan35@yandex.com
# abc@yandex.com
# mkm@yandex.com
# cy10@aol.com
# cyc13@aol.com
# cyc14@aol.com
# cyc15@proton.com
# cyc16@proton.com
# cyc43@proton.com
# cyc44@proton.com
# cyc64@proton.com
# cyc65@proton.com
