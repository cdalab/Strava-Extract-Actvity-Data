# %%
import re
import time as t
import pandas as pd
import pickle as pk
from selenium import webdriver
from selenium.webdriver.support.wait import WebDriverWait
from bs4 import BeautifulSoup

# %%
STRAVA_URL = 'https://www.strava.com'
password = r'1357WorkWork!'
p = '1357Worker!'
usernames = [
    r'kvspek@gmail.com',
    r'spektork@post.bgu.ac.il',
    r'kev_backup@yahoo.com',
    r'cool_table@yahoo.com',
    r'cool_table2@yahoo.com',
    r'cool_table3@yahoo.com',
    r'cool_table4@yahoo.com',
    r'cool_table5@yahoo.com',
]

username_backup = r'kev_backup@yahoo.com'
password = r'1357Backup!'

# %% [markdown]
# ## Prepare chrome driver and sign in to Strava

# %%
def chrome_driver(username, password):
    options = webdriver.ChromeOptions()
    options.add_argument('headless')

    # start chrome browser
    browser = webdriver.Chrome(options=options)

    browser.get(STRAVA_URL + '/login')
    email = browser.find_element_by_id("email")
    password = browser.find_element_by_id("password")

    email.send_keys(username)
    password.send_keys(password)
    
    browser.find_element_by_id("login-button").click()
    print(browser.current_url)
    return browser

# %% [markdown]
# ## Extract rider activities

# %%
workout_columns = ['workout_id' ,'workout_tp_id','workout_strava_id', 'cyclist_id', 'type' ,'tags', 'workout_week', 'workout_month', 'workout_datetime', 'total_time', 'workout_title', 'cyclist_mass', 'elevation_gain', 'elevation_loss', 'elevation_average', 'elevation_maximum', 'elevation_minimum', 'temp_avg', 'temp_min', 'temp_max','_1000_to_1500_m', '_1500_to_2000_m', '_2000_tp_2500_m', '_2500_to_3000_m', '_3000_to_3500_m', 'relative_effort', 'training_load', 'intensity', 'distance', 'energy', 'calories', 'if', 'tss_actual', 'tss_calculation_method', 'hidden','locked']
workout_hrs_columns = ['workout_id', 'hr_maximum', 'hr_average','hr_5_seconds', 'hr_10_seconds', 'hr_12_seconds', 'hr_20_seconds', 'hr_30_seconds', 'hr_1_minute', 'hr_2_minutes', 'hr_5_minutes', 'hr_6_minutes', 'hr_10_minutes', 'hr_12_minutes', 'hr_20_minutes', 'hr_30_minutes', 'hr_1_hour', 'hr_90_minutes', 'hr_3_hours', 'hr_zone_1', 'hr_zone_2', 'hr_zone_3', 'hr_zone_4', 'hr_zone_5', 'hr_zone_1_min', 'hr_zone_2_min', 'hr_zone_3_min', 'hr_zone_4_min' ,'hr_zone_5_min']
workout_cadences_columns = ['workout_id', 'cadence_5_seconds', 'cadence_10_seconds', 'cadence_12_seconds', 'cadence_20_seconds', 'cadence_30_seconds', 'cadence_1_minute', 'cadence_2_minutes', 'cadence_5_minutes', 'cadence_6_minutes', 'cadence_10_minutes', 'cadence_12_minutes', 'cadence_20_minutes', 'cadence_30_minutes', 'cadence_1_hour', 'cadence_90_minutes', 'cadence_3_hours', 'cadence_maximum', 'cadence_average']
workout_powers_columns = ['workout_id', 'power_maximum', 'power_average', 'normalized_power', 'power_5_seconds', 'power_10_seconds', 'power_12_seconds', 'power_20_seconds', 'power_30_seconds', 'power_1_minute', 'power_2_minutes', 'power_5_minutes', 'power_6_minutes', 'power_10_minutes', 'power_12_minutes', 'power_20_minutes', 'power_30_minutes', 'power_1_hour', 'power_90_minutes', 'power_3_hours', 'power_zone_1', 'power_zone_2', 'power_zone_3', 'power_zone_4', 'power_zone_5', 'power_zone_6', 'power_zone_7', 'power_zone_1_min', 'power_zone_2_min', 'power_zone_3_min', 'power_zone_4_min', 'power_zone_5_min', 'power_zone_6_min', 'power_zone_7_min']
workout_speeds_columns = ['workout_id', 'speed_maximum', 'speed_average', 'speed_5_seconds', 'speed_10_seconds', 'speed_12_seconds', 'speed_20_seconds', 'speed_30_seconds', 'speed_1_minute', 'speed_2_minutes', 'speed_5_minutes', 'speed_6_minutes', 'speed_10_minutes', 'speed_12_minutes', 'speed_20_minutes', 'speed_30_minutes', 'speed_1_hour', 'speed_90_minutes', 'speed_3_hours', 'speed_zone_1', 'speed_zone_2', 'speed_zone_3', 'speed_zone_4', 'speed_zone_5', 'speed_zone_6', 'speed_zone_7', 'speed_zone_1_min', 'speed_zone_2_min', 'speed_zone_3_min', 'speed_zone_4_min', 'speed_zone_5_min', 'speed_zone_6_min', 'speed_zone_7_min']
   
class Workout:
    def __init__(self)

# %%
 class Rider:
    def __init__(self, rider_name, rider_url):
        self.rider_name = rider_name.lower()
        self.rider_url = rider_url
        self.activity_links = set()
        self.links = []
        
    def __repr__(self):
        return f'Rider_link: {self.rider_url}, Rider name: {self.rider_name}'

# %%
class GetActivities(): 
    
    def __init__(self, username, riders, years = list(range(2015,2022)), months = list(range(1,13))):
        self.activity_links = set()
        self.riders = riders
        self.years = years
        self.months = months
        self.username = username
        self.STRAVA_URL = 'https://www.strava.com'
        
    def _open_driver(self):
        
        options = webdriver.ChromeOptions()
        options.add_argument('headless')
        
        self.browser = webdriver.Chrome(options=options)
        URL = self.STRAVA_URL + '/login'
        
        self.browser.get(URL)
        email = self.browser.find_element_by_id("email")
        password = self.browser.find_element_by_id("password")

        email.send_keys(self.username)
        password.send_keys('12345678')
        
        self.browser.find_element_by_id("login-button").click()
        t.sleep(1)
        print(self.browser.current_url)
        
    def _close_driver(self):
        self.browser.close()
        
    def extract_activities(self):
        
        self._open_driver()
        problematic_riders = []
        for rider in self.riders:
            
            self.browser.get(rider.rider_url)
            t.sleep(1)
            
            print(rider)
            try:
                # Click on 'monthly' button so that the date inteverals would be smaller
                monthly_xpath = '//*[@id="interval-graph-controls"]/ul/li[2]/ul/li[2]/a'
                interval_xpath = '//*[@id="interval-graph-columns"]/div/ul[2]'

                soup = BeautifulSoup(self.browser.page_source, 'html.parser')
                date_intervals = soup.find('div', {'class': 'drop-down-menu drop-down-sm enabled'})
                temp_links = date_intervals.find_all('a')

                date_links = []
                for temp_link in temp_links:
                    link = STRAVA_URL + temp_link['href']
                    link = link.replace('week', 'month')
                    date_links.append(link)


                current_link_year = soup.find('h2', {'class': 'text-callout left'}).text[-5:-1]
                current_link = date_links[0]
                interval_exmaple = re.search("interval=.*&", current_link).group(0)
                current_link = current_link.replace(interval_exmaple[-7:-3], current_link_year)
                current_link = current_link[:-1] + '0'
                date_links.insert(0, current_link)

                self.links = []
                interval_soups = []
                prev_url = self.browser.current_url
                for link in date_links:

                    interval1 = re.search("interval=.*&", link).group(0)
                    year = int(interval1[-7:-3])

                    if year-1 in self.years:

                        for month in range(7,13):
                            if month not in self.months:
                                continue

                            month_string = str(month) if month >= 10 else f'0{month}'
                            interval2 = interval1.replace(str(year)+interval1[-3:-1], str(year-1)+month_string)
                            rider.links.append(link.replace(interval1, interval2))

                    if year in self.years:

                        for month in range(1,8):
                            if month not in self.months:
                                continue

                            interval2 = interval1.replace(str(year)+interval1[-3:-1], str(year)+f'0{month}')
                            rider.links.append(link.replace(interval1, interval2))
                            
            except:
                problematic_riders.append(rider)
            
        self.riders = [rider for rider in self.riders if rider not in problematic_riders]  
        self._close_driver()

    def run(self):
        
        self._open_driver()

        prev = set()
        curr = set()
        for rider in self.riders:
            
            for link in rider.links:
                
                self.browser.get(link)
                site_soup = BeautifulSoup(self.browser.page_source, 'html.parser')

                if site_soup.find('html')['class'][0] == 'logged-out': # logged out ...
                    print(f'logged out...')
                    return

                print(f'{self.browser.current_url}') 
                t.sleep(2)
                timeout = t.time() + 15
                new_curr = set()

                while curr == prev:
                    t.sleep(1)
                    graph_soup = BeautifulSoup(self.browser.page_source, 'html.parser')
                    group_feed_activities = graph_soup.find_all('div', {'class': 'feed-entry group-activity'})
                    normal_activities = graph_soup.find_all('div', {'class': 'activity feed-entry entity-details'})

                    for group_feed_activity in group_feed_activities:
                        # loop through all group activities
                        group_feed_entry_body = group_feed_activity.find('div', {'class': 'entry-body'})
                        group_feed_link = group_feed_entry_body.find('a')
                        new_curr.add(self.STRAVA_URL + group_feed_link.get('href'))

                    for normal_activity in normal_activities:
                        # loop through all normal activities
                        normal_activity_entry_body = normal_activity.find('div', {'class': 'entry-body'})
                        normal_activity_link = normal_activity_entry_body.find('a')
                        new_curr.add(self.STRAVA_URL + normal_activity_link.get('href'))
                    curr = new_curr

                    if t.time() > timeout:
                        break

                prev = curr

                rider.activity_links = self.activity_links.union(curr)

        self._close_driver()

# %%
def valid_rider_url(url):
    pattern = re.compile("https://www.strava.com/[a-zA-Z]+/[0-9]+$")
    found = pattern.search(url)
    if not found:
        return False
    return True

# %%
activity_links = set()

# %%
df = pd.read_csv('data/Fetch_url_cyclists.csv')
df = df[df['url'].notna()]
riders = []
for index, row in df.iterrows():
    rider = Rider(row['full_name'], row['url'])
    if valid_rider_url(rider.rider_url):
        riders.append(rider)

# %%
get_activities = GetActivities(usernames[1], riders)
get_activities.extract_activities()
# Out:
# https://www.strava.com/onboarding
# Rider_link: https://www.strava.com/athletes/3249116, Rider name: abrahamsen jonas
# Rider_link: https://www.strava.com/athletes/6390713, Rider name: adrià roger
# Rider_link: https://www.strava.com/pros/37167909, Rider name: affini edoardo
# Rider_link: https://www.strava.com/athletes/38162237, Rider name: alba juan diego
# Rider_link: https://www.strava.com/pros/3488983, Rider name: albanese vincenzo
# Rider_link: https://www.strava.com/athletes/21536765, Rider name: aleotti giovanni
# Rider_link: https://www.strava.com/pros/12542977, Rider name: anacona winner
# Rider_link: https://www.strava.com/athletes/10443289, Rider name: andersen idar
# Rider_link: https://www.strava.com/athletes/2346552, Rider name: anderson edward
# Rider_link: https://www.strava.com/athletes/26726869, Rider name: aranburu jokin
# Rider_link: https://www.strava.com/athletes/12337203, Rider name: arashiro yukiya
# Rider_link: https://www.strava.com/pros/2276607, Rider name: arcas jorge
# Rider_link: https://www.strava.com/athletes/1936233, Rider name: arensman thymen
# Rider_link: https://www.strava.com/athletes/17546094, Rider name: aular orluis
# Rider_link: https://www.strava.com/athletes/6094073, Rider name: ávila edwin
# Rider_link: https://www.strava.com/athletes/10780095, Rider name: ayuso juan
# Rider_link: https://www.strava.com/athletes/3060100, Rider name: azurmendi ibai
# Rider_link: https://www.strava.com/pros/23726463, Rider name: backaert frederik
# Rider_link: https://www.strava.com/athletes/4419459, Rider name: badilatti matteo
# Rider_link: https://www.strava.com/athletes/19593505, Rider name: bagioli andrea
# Rider_link: https://www.strava.com/athletes/2476243, Rider name: bagioli nicola
# Rider_link: https://www.strava.com/athletes/2566327, Rider name: bais davide
# Rider_link: https://www.strava.com/athletes/2573969, Rider name: bais mattia
# Rider_link: https://www.strava.com/pros/3943249, Rider name: bakelants jan
# Rider_link: https://www.strava.com/athletes/1930273, Rider name: ballerini davide
# Rider_link: https://www.strava.com/athletes/7019829, Rider name: barbier rudy
# Rider_link: https://www.strava.com/pros/722861, Rider name: barguil warren
# Rider_link: https://www.strava.com/athletes/26007448, Rider name: bartolozzi andrea
# Rider_link: https://www.strava.com/pros/622396, Rider name: bassett stephen
# Rider_link: https://www.strava.com/athletes/16571022, Rider name: battistella samuele
# Rider_link: https://www.strava.com/athletes/8409483, Rider name: bayer tobias
# Rider_link: https://www.strava.com/athletes/1597609, Rider name: behringer oliver
# Rider_link: https://www.strava.com/pros/2508843, Rider name: belletti manuel
# Rider_link: https://www.strava.com/athletes/7652767, Rider name: bellicaud jeremy
# Rider_link: https://www.strava.com/athletes/1326031, Rider name: benedetti cesare
# Rider_link: https://www.strava.com/pros/880187, Rider name: bennett george
# Rider_link: https://www.strava.com/athletes/326585, Rider name: bennett sean
# Rider_link: https://www.strava.com/pros/1128302, Rider name: benoot tiesj
# Rider_link: https://www.strava.com/pros/6068080, Rider name: beppu fumiyuki
# Rider_link: https://www.strava.com/pros/2119306, Rider name: bernal egan
# Rider_link: https://www.strava.com/pros/1903938, Rider name: bernard julien
# Rider_link: https://www.strava.com/athletes/13308515, Rider name: berrade urko
# Rider_link: https://www.strava.com/pros/2916501, Rider name: bidard françois
# Rider_link: https://www.strava.com/athletes/2305481, Rider name: biermans jenthe
# Rider_link: https://www.strava.com/athletes/4671192, Rider name: bissegger stefan
# Rider_link: https://www.strava.com/athletes/3673069, Rider name: bizkarra mikel
# Rider_link: https://www.strava.com/athletes/4013766, Rider name: blikra erlend
# Rider_link: https://www.strava.com/athletes/36495113, Rider name: boev igor
# Rider_link: https://www.strava.com/athletes/41905231, Rider name: bohli tom
# Rider_link: https://www.strava.com/athletes/616061, Rider name: boivin guillaume
# Rider_link: https://www.strava.com/athletes/1331421, Rider name: bol cees
# Rider_link: https://www.strava.com/athletes/9722733, Rider name: bonifazio leonardo
# Rider_link: https://www.strava.com/pros/1554175, Rider name: bonifazio niccolò
# Rider_link: https://www.strava.com/pros/4018952, Rider name: bonnamour franck
# Rider_link: https://www.strava.com/athletes/26475512, Rider name: bookwalter brent
# Rider_link: https://www.strava.com/athletes/11168033, Rider name: bou joan
# Rider_link: https://www.strava.com/pros/1993533, Rider name: bouwman koen
# Rider_link: https://www.strava.com/pros/1170160, Rider name: brand sam
# Rider_link: https://www.strava.com/pros/266080, Rider name: brändle matthias
# Rider_link: https://www.strava.com/athletes/26353981, Rider name: bravo garikoitz
# Rider_link: https://www.strava.com/pros/1084629, Rider name: britton rob
# Rider_link: https://www.strava.com/pros/259470, Rider name: brown nathan
# Rider_link: https://www.strava.com/athletes/8411551, Rider name: brunel alexys
# Rider_link: https://www.strava.com/pros/2685219, Rider name: buchmann emanuel
# Rider_link: https://www.strava.com/athletes/12274525, Rider name: burgaudeau mathieu
# Rider_link: https://www.strava.com/pros/1803986, Rider name: burghardt marcus
# Rider_link: https://www.strava.com/athletes/2542098, Rider name: bystrøm sven erik
# Rider_link: https://www.strava.com/athletes/3966534, Rider name: cam maxime
# Rider_link: https://www.strava.com/athletes/8367340, Rider name: cañaveral johnatan
# Rider_link: https://www.strava.com/athletes/15104335, Rider name: carapaz richard
# Rider_link: https://www.strava.com/athletes/20511815, Rider name: carboni giovanni
# Rider_link: https://www.strava.com/athletes/1577875, Rider name: carisey clément
# Rider_link: https://www.strava.com/athletes/3611828, Rider name: carr simon
# Rider_link: https://www.strava.com/pros/3983729, Rider name: castrillo jaime
# Rider_link: https://www.strava.com/athletes/2373068, Rider name: castrique jonas
# Rider_link: https://www.strava.com/athletes/3490359, Rider name: cataford alexander
# Rider_link: https://www.strava.com/athletes/10887608, Rider name: cattaneo mattia
# Rider_link: https://www.strava.com/pros/2203430, Rider name: cavagna rémi
# Rider_link: https://www.strava.com/athletes/4027056, Rider name: charmig anthon
# Rider_link: https://www.strava.com/athletes/4119801, Rider name: chaves esteban
# Rider_link: https://www.strava.com/pros/2136208, Rider name: cherel mikaël
# Rider_link: https://www.strava.com/athletes/20388790, Rider name: cherkasov nikolay
# Rider_link: https://www.strava.com/athletes/46449479, Rider name: chirico luca
# Rider_link: https://www.strava.com/pros/4980290, Rider name: claeys dimitri
# Rider_link: https://www.strava.com/athletes/2655853, Rider name: colbrelli sonny
# Rider_link: https://www.strava.com/athletes/3800500, Rider name: colleoni kevin
# Rider_link: https://www.strava.com/pros/7604023, Rider name: colman alex
# Rider_link: https://www.strava.com/athletes/5276222, Rider name: combaud romain
# Rider_link: https://www.strava.com/athletes/10925190, Rider name: conca filippo
# Rider_link: https://www.strava.com/athletes/2824377, Rider name: consonni simone
# Rider_link: https://www.strava.com/athletes/7633523, Rider name: coquard bryan
# Rider_link: https://www.strava.com/athletes/63456809, Rider name: costa rui
# Rider_link: https://www.strava.com/athletes/11516170, Rider name: jones taj
# Rider_link: https://www.strava.com/athletes/557974, Rider name: jorgenson matteo
# Rider_link: https://www.strava.com/athletes/3418221, Rider name: joyce colin
# Rider_link: https://www.strava.com/pros/27117126, Rider name: kämna lennard
# Rider_link: https://www.strava.com/athletes/14899637, Rider name: kamp alexander
# Rider_link: https://www.strava.com/pros/6033817, Rider name: kamstra brian
# Rider_link: https://www.strava.com/pros/2835838, Rider name: keisse iljo
# Rider_link: https://www.strava.com/pros/2590526, Rider name: kirsch alex
# Rider_link: https://www.strava.com/pros/4067146, Rider name: koch jonas
# Rider_link: https://www.strava.com/athletes/26816676, Rider name: konychev alexander
# Rider_link: https://www.strava.com/athletes/27682210, Rider name: kragh andersen søren
# Rider_link: https://www.strava.com/athletes/9232885, Rider name: kristoff alexander
# Rider_link: https://www.strava.com/athletes/8783869, Rider name: kron andreas
# Rider_link: https://www.strava.com/athletes/1783594, Rider name: kulset kristian
# Rider_link: https://www.strava.com/pros/133606, Rider name: küng stefan
# Rider_link: https://www.strava.com/athletes/254096, Rider name: kuss sepp
# Rider_link: https://www.strava.com/athletes/16044924, Rider name: kuzmin anton
# Rider_link: https://www.strava.com/pros/2111315, Rider name: laas martin
# Rider_link: https://www.strava.com/athletes/7348371, Rider name: ladagnous matthieu
# Rider_link: https://www.strava.com/athletes/11477652, Rider name: lammertink maurits
# Rider_link: https://www.strava.com/pros/2916067, Rider name: lampaert yves
# Rider_link: https://www.strava.com/pros/3834960, Rider name: laporte christophe
# Rider_link: https://www.strava.com/athletes/8089198, Rider name: lastra jonathan
# Rider_link: https://www.strava.com/pros/7347052, Rider name: latour pierre
# Rider_link: https://www.strava.com/athletes/9567228, Rider name: lazkano oier
# Rider_link: https://www.strava.com/pros/3175306, Rider name: le turnier mathias
# Rider_link: https://www.strava.com/pros/1880115, Rider name: lemoine cyril
# Rider_link: https://www.strava.com/athletes/2922866, Rider name: leysen senne
# Rider_link: https://www.strava.com/athletes/19161146, Rider name: lienhard fabian
# Rider_link: https://www.strava.com/pros/1614461, Rider name: livyns arjen
# Rider_link: https://www.strava.com/athletes/7097988, Rider name: lópez-cózar juan antonio
# Rider_link: https://www.strava.com/pros/6860614, Rider name: louvel matis
# Rider_link: https://www.strava.com/pros/2420222, Rider name: ludvigsson tobias
# Rider_link: https://www.strava.com/athletes/19220743, Rider name: lutsenko alexey
# Rider_link: https://www.strava.com/athletes/19914823, Rider name: mäder gino
# Rider_link: https://www.strava.com/pros/2404608, Rider name: madouas valentin
# Rider_link: https://www.strava.com/athletes/1732923, Rider name: malucelli matteo
# Rider_link: https://www.strava.com/athletes/277422, Rider name: mannion gavin
# Rider_link: https://www.strava.com/athletes/7172433, Rider name: manzin lorrenzo
# Rider_link: https://www.strava.com/pros/6898466, Rider name: marcato marco
# Rider_link: https://www.strava.com/athletes/4929761, Rider name: mareczko jakub
# Rider_link: https://www.strava.com/athletes/2652993, Rider name: marengo umberto
# Rider_link: https://www.strava.com/pros/1675856, Rider name: martens paul
# Rider_link: https://www.strava.com/pros/1668485, Rider name: theuns edward
# Rider_link: https://www.strava.com/pros/3417988, Rider name: thijssen gerben
# Rider_link: https://www.strava.com/athletes/1700745, Rider name: thomas benjamin
# Rider_link: https://www.strava.com/pros/269031, Rider name: thwaites scott
# Rider_link: https://www.strava.com/athletes/13764349, Rider name: tiberi antonio
# Rider_link: https://www.strava.com/athletes/3194779, Rider name: tonelli alessandro
# Rider_link: https://www.strava.com/athletes/584854, Rider name: torres albert
# Rider_link: https://www.strava.com/athletes/2926114, Rider name: touzé damien
# Rider_link: https://www.strava.com/athletes/1729691, Rider name: trarieux julien
# Rider_link: https://www.strava.com/athletes/1311227, Rider name: troia oliviero
# Rider_link: https://www.strava.com/pros/2716222, Rider name: turek daniel
# Rider_link: https://www.strava.com/pros/1514397, Rider name: urán rigoberto
# Rider_link: https://www.strava.com/athletes/13682757, Rider name: urianstad martin
# Rider_link: https://www.strava.com/athletes/26479654, Rider name: vacek karel
# Rider_link: https://www.strava.com/athletes/28007299, Rider name: vahtra norman
# Rider_link: https://www.strava.com/pros/2109462, Rider name: valgren michael
# Rider_link: https://www.strava.com/pros/5968580, Rider name: vallée boris
# Rider_link: https://www.strava.com/athletes/3046537, Rider name: valter attila
# Rider_link: https://www.strava.com/athletes/25407057, Rider name: valverde alejandro
# Rider_link: https://www.strava.com/pros/189040, Rider name: van aert wout
# Rider_link: https://www.strava.com/pros/387215, Rider name: van asbroeck tom
# Rider_link: https://www.strava.com/athletes/1867924, Rider name: van den bossche fabio
# Rider_link: https://www.strava.com/pros/542394, Rider name: van der poel david
# Rider_link: https://www.strava.com/pros/559834, Rider name: van der poel mathieu
# Rider_link: https://www.strava.com/athletes/4581235, Rider name: van elzakker wout
# Rider_link: https://www.strava.com/pros/7660926, Rider name: van emden jos
# Rider_link: https://www.strava.com/pros/1149352, Rider name: van empel etienne
# Rider_link: https://www.strava.com/pros/3391355, Rider name: van garderen tejay
# Rider_link: https://www.strava.com/athletes/1164101, Rider name: van hooydonck nathan
# Rider_link: https://www.strava.com/pros/957045, Rider name: van kessel corné
# Rider_link: https://www.strava.com/pros/4227606, Rider name: van melsen kévin
# Rider_link: https://www.strava.com/athletes/3855537, Rider name: van moer brent
# Rider_link: https://www.strava.com/pros/7967844, Rider name: van poucke aaron
# Rider_link: https://www.strava.com/athletes/13125039, Rider name: van wilder ilan
# Rider_link: https://www.strava.com/pros/2021447, Rider name: van winden dennis
# Rider_link: https://www.strava.com/athletes/2393015, Rider name: vanbilsen kenneth
# Rider_link: https://www.strava.com/athletes/14929135, Rider name: vanhoof ward
# Rider_link: https://www.strava.com/athletes/24668658, Rider name: vauquelin kevin
# Rider_link: https://www.strava.com/pros/522423, Rider name: velasco simone
# Rider_link: https://www.strava.com/athletes/6547917, Rider name: venner quentin
# Rider_link: https://www.strava.com/pros/1932146, Rider name: venturini clément
# Rider_link: https://www.strava.com/pros/3123001, Rider name: vergaerde otto
# Rider_link: https://www.strava.com/athletes/29140444, Rider name: vermaerke kevin
# Rider_link: https://www.strava.com/athletes/9421925, Rider name: vermeersch florian
# Rider_link: https://www.strava.com/pros/1978998, Rider name: vermeersch gianni
# Rider_link: https://www.strava.com/pros/3092222, Rider name: verschaeve viktor
# Rider_link: https://www.strava.com/pros/1123635, Rider name: vervaeke louis
# Rider_link: https://www.strava.com/athletes/20187980, Rider name: vervloesem xandres
# Rider_link: https://www.strava.com/pros/13084830, Rider name: verwilst aaron
# Rider_link: https://www.strava.com/athletes/3005446, Rider name: viel mattia
# Rider_link: https://www.strava.com/pros/1756844, Rider name: villella davide
# Rider_link: https://www.strava.com/athletes/4057312, Rider name: vine jay
# Rider_link: https://www.strava.com/athletes/10495058, Rider name: vingegaard jonas
# Rider_link: https://www.strava.com/athletes/1675720, Rider name: vinjebo emil
# Rider_link: https://www.strava.com/pros/2957348, Rider name: visconti giovanni
# Rider_link: https://www.strava.com/athletes/12726147, Rider name: viviani attilio
# Rider_link: https://www.strava.com/athletes/2333960, Rider name: vliegen loïc
# Rider_link: https://www.strava.com/pros/1934385, Rider name: vuillermoz alexis
# Rider_link: https://www.strava.com/pros/18849972, Rider name: wackermann luca
# Rider_link: https://www.strava.com/athletes/17599254, Rider name: wærenskjold søren
# Rider_link: https://www.strava.com/pros/704876, Rider name: walsleben philipp
# Rider_link: https://www.strava.com/pros/197359, Rider name: warbasse larry
# Rider_link: https://www.strava.com/pros/19342022, Rider name: warlop jordi
# Rider_link: https://www.strava.com/athletes/16358800, Rider name: welten bram
# Rider_link: https://www.strava.com/pros/3356275, Rider name: whelan james
# Rider_link: https://www.strava.com/athletes/1109766, Rider name: williams stephen
# Rider_link: https://www.strava.com/pros/425147, Rider name: woods michael
# Rider_link: https://www.strava.com/athletes/2109406, Rider name: würtz schmidt mads
# Rider_link: https://www.strava.com/pros/2557063, Rider name: zabel rick
# Rider_link: https://www.strava.com/athletes/39169689, Rider name: zana filippo
# Rider_link: https://www.strava.com/athletes/3689004, Rider name: zardini edoardo
# Rider_link: https://www.strava.com/activities/577057091, Rider name: zeits andrey
# Rider_link: https://www.strava.com/athletes/5284986, Rider name: zimmermann georg
# Rider_link: https://www.strava.com/athletes/6973093, Rider name: zingle axel
# Rider_link: https://www.strava.com/athletes/1015750, Rider name: jans roy
# Rider_link: https://www.strava.com/athletes/24521924, Rider name: ponomar andrii
# Rider_link: https://www.strava.com/pros/2469093, Rider name: räim mihkel
# Rider_link: https://www.strava.com/athletes/1150402, Rider name: lemus luis
# Rider_link: https://www.strava.com/athletes/365015, Rider name: dempster zak
# Rider_link: https://www.strava.com/athletes/1492619, Rider name: goldstein roy
# Rider_link: https://www.strava.com/athletes/5943644, Rider name: schreurs hamish
# Rider_link: https://www.strava.com/athletes/759393, Rider name: dunne conor
# 473
# 433

# %%
pickle = pickle.dumps(get_activities.riders)

# %%
with open('data/riders.pickle', 'wb') as handle:
    pk.dump(get_activities.riders, handle, protocol=pk.HIGHEST_PROTOCOL)

# %%
with open('data/riders.pickle', 'rb') as handle:
    riders = pk.load(handle)

# %%
# Out:
# 433
